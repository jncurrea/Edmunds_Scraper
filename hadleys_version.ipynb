# %% [markdown]
# # Group Assignment 1

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np 
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from collections import Counter
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import nltk
from nltk.corpus import stopwords
#nltk.download('stopwords')
import itertools
from sklearn.manifold import MDS

pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.expand_frame_repr', False)  # Prevent wrapping to multiple lines

# %% [markdown]
# ## Scraper Development

# %%
def scrape_page(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")

        messages = soup.find_all("div", class_ = "Message userContent")

        dates = soup.find_all("time")

        data = []

        for message, date in zip(messages, dates):
            message_text = message.get_text(strip = True)
            date_text = date.get("title")
            data.append({"Date": date_text, "Message": message_text})

        return data


def scrape_forum(base_url, total_pages):
    all_data = []

    for page_num in range(1, total_pages + 1):
        page_url = f"{base_url}/p{page_num}"
        print(f"Scraping page {page_num}: {page_url}")
        page_data = scrape_page(page_url)
        all_data.extend(page_data)
    return all_data

# %%
base_url = "https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans"
total_pages = 300
forum_data = scrape_forum(base_url, total_pages)
messagedata = pd.DataFrame(forum_data)
messagedata.to_csv("messagedata.csv", index = False)
len(messagedata)
# Out:
# Scraping page 1: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p1
# Scraping page 2: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p2
# Scraping page 3: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p3
# Scraping page 4: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p4
# Scraping page 5: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p5
# Scraping page 6: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p6
# Scraping page 7: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p7
# Scraping page 8: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p8
# Scraping page 9: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p9
# Scraping page 10: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p10
# Scraping page 11: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p11
# Scraping page 12: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p12
# Scraping page 13: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p13
# Scraping page 14: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p14
# Scraping page 15: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p15
# Scraping page 16: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p16
# Scraping page 17: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p17
# Scraping page 18: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p18
# Scraping page 19: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p19
# Scraping page 20: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p20
# Scraping page 21: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p21
# Scraping page 22: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p22
# Scraping page 23: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p23
# Scraping page 24: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p24
# Scraping page 25: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p25
# Scraping page 26: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p26
# Scraping page 27: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p27
# Scraping page 28: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p28
# Scraping page 29: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p29
# Scraping page 30: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p30
# Scraping page 31: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p31
# Scraping page 32: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p32
# Scraping page 33: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p33
# Scraping page 34: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p34
# Scraping page 35: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p35
# Scraping page 36: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p36
# Scraping page 37: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p37
# Scraping page 38: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p38
# Scraping page 39: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p39
# Scraping page 40: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p40
# Scraping page 41: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p41
# Scraping page 42: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p42
# Scraping page 43: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p43
# Scraping page 44: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p44
# Scraping page 45: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p45
# Scraping page 46: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p46
# Scraping page 47: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p47
# Scraping page 48: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p48
# Scraping page 49: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p49
# Scraping page 50: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p50
# Scraping page 51: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p51
# Scraping page 52: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p52
# Scraping page 53: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p53
# Scraping page 54: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p54
# Scraping page 55: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p55
# Scraping page 56: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p56
# Scraping page 57: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p57
# Scraping page 58: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p58
# Scraping page 59: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p59
# Scraping page 60: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p60
# Scraping page 61: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p61
# Scraping page 62: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p62
# Scraping page 63: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p63
# Scraping page 64: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p64
# Scraping page 65: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p65
# Scraping page 66: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p66
# Scraping page 67: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p67
# Scraping page 68: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p68
# Scraping page 69: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p69
# Scraping page 70: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p70
# Scraping page 71: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p71
# Scraping page 72: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p72
# Scraping page 73: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p73
# Scraping page 74: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p74
# Scraping page 75: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p75
# Scraping page 76: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p76
# Scraping page 77: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p77
# Scraping page 78: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p78
# Scraping page 79: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p79
# Scraping page 80: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p80
# Scraping page 81: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p81
# Scraping page 82: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p82
# Scraping page 83: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p83
# Scraping page 84: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p84
# Scraping page 85: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p85
# Scraping page 86: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p86
# Scraping page 87: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p87
# Scraping page 88: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p88
# Scraping page 89: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p89
# Scraping page 90: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p90
# Scraping page 91: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p91
# Scraping page 92: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p92
# Scraping page 93: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p93
# Scraping page 94: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p94
# Scraping page 95: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p95
# Scraping page 96: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p96
# Scraping page 97: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p97
# Scraping page 98: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p98
# Scraping page 99: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p99
# Scraping page 100: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p100
# Scraping page 101: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p101
# Scraping page 102: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p102
# Scraping page 103: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p103
# Scraping page 104: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p104
# Scraping page 105: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p105
# Scraping page 106: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p106
# Scraping page 107: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p107
# Scraping page 108: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p108
# Scraping page 109: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p109
# Scraping page 110: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p110
# Scraping page 111: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p111
# Scraping page 112: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p112
# Scraping page 113: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p113
# Scraping page 114: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p114
# Scraping page 115: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p115
# Scraping page 116: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p116
# Scraping page 117: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p117
# Scraping page 118: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p118
# Scraping page 119: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p119
# Scraping page 120: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p120
# Scraping page 121: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p121
# Scraping page 122: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p122
# Scraping page 123: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p123
# Scraping page 124: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p124
# Scraping page 125: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p125
# Scraping page 126: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p126
# Scraping page 127: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p127
# Scraping page 128: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p128
# Scraping page 129: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p129
# Scraping page 130: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p130
# Scraping page 131: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p131
# Scraping page 132: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p132
# Scraping page 133: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p133
# Scraping page 134: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p134
# Scraping page 135: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p135
# Scraping page 136: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p136
# Scraping page 137: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p137
# Scraping page 138: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p138
# Scraping page 139: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p139
# Scraping page 140: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p140
# Scraping page 141: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p141
# Scraping page 142: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p142
# Scraping page 143: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p143
# Scraping page 144: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p144
# Scraping page 145: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p145
# Scraping page 146: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p146
# Scraping page 147: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p147
# Scraping page 148: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p148
# Scraping page 149: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p149
# Scraping page 150: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p150
# Scraping page 151: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p151
# Scraping page 152: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p152
# Scraping page 153: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p153
# Scraping page 154: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p154
# Scraping page 155: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p155
# Scraping page 156: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p156
# Scraping page 157: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p157
# Scraping page 158: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p158
# Scraping page 159: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p159
# Scraping page 160: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p160
# Scraping page 161: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p161
# Scraping page 162: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p162
# Scraping page 163: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p163
# Scraping page 164: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p164
# Scraping page 165: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p165
# Scraping page 166: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p166
# Scraping page 167: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p167
# Scraping page 168: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p168
# Scraping page 169: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p169
# Scraping page 170: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p170
# Scraping page 171: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p171
# Scraping page 172: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p172
# Scraping page 173: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p173
# Scraping page 174: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p174
# Scraping page 175: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p175
# Scraping page 176: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p176
# Scraping page 177: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p177
# Scraping page 178: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p178
# Scraping page 179: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p179
# Scraping page 180: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p180
# Scraping page 181: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p181
# Scraping page 182: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p182
# Scraping page 183: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p183
# Scraping page 184: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p184
# Scraping page 185: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p185
# Scraping page 186: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p186
# Scraping page 187: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p187
# Scraping page 188: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p188
# Scraping page 189: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p189
# Scraping page 190: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p190
# Scraping page 191: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p191
# Scraping page 192: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p192
# Scraping page 193: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p193
# Scraping page 194: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p194
# Scraping page 195: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p195
# Scraping page 196: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p196
# Scraping page 197: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p197
# Scraping page 198: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p198
# Scraping page 199: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p199
# Scraping page 200: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p200
# Scraping page 201: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p201
# Scraping page 202: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p202
# Scraping page 203: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p203
# Scraping page 204: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p204
# Scraping page 205: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p205
# Scraping page 206: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p206
# Scraping page 207: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p207
# Scraping page 208: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p208
# Scraping page 209: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p209
# Scraping page 210: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p210
# Scraping page 211: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p211
# Scraping page 212: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p212
# Scraping page 213: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p213
# Scraping page 214: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p214
# Scraping page 215: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p215
# Scraping page 216: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p216
# Scraping page 217: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p217
# Scraping page 218: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p218
# Scraping page 219: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p219
# Scraping page 220: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p220
# Scraping page 221: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p221
# Scraping page 222: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p222
# Scraping page 223: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p223
# Scraping page 224: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p224
# Scraping page 225: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p225
# Scraping page 226: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p226
# Scraping page 227: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p227
# Scraping page 228: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p228
# Scraping page 229: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p229
# Scraping page 230: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p230
# Scraping page 231: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p231
# Scraping page 232: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p232
# Scraping page 233: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p233
# Scraping page 234: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p234
# Scraping page 235: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p235
# Scraping page 236: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p236
# Scraping page 237: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p237
# Scraping page 238: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p238
# Scraping page 239: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p239
# Scraping page 240: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p240
# Scraping page 241: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p241
# Scraping page 242: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p242
# Scraping page 243: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p243
# Scraping page 244: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p244
# Scraping page 245: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p245
# Scraping page 246: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p246
# Scraping page 247: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p247
# Scraping page 248: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p248
# Scraping page 249: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p249
# Scraping page 250: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p250
# Scraping page 251: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p251
# Scraping page 252: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p252
# Scraping page 253: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p253
# Scraping page 254: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p254
# Scraping page 255: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p255
# Scraping page 256: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p256
# Scraping page 257: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p257
# Scraping page 258: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p258
# Scraping page 259: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p259
# Scraping page 260: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p260
# Scraping page 261: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p261
# Scraping page 262: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p262
# Scraping page 263: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p263
# Scraping page 264: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p264
# Scraping page 265: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p265
# Scraping page 266: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p266
# Scraping page 267: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p267
# Scraping page 268: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p268
# Scraping page 269: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p269
# Scraping page 270: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p270
# Scraping page 271: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p271
# Scraping page 272: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p272
# Scraping page 273: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p273
# Scraping page 274: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p274
# Scraping page 275: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p275
# Scraping page 276: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p276
# Scraping page 277: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p277
# Scraping page 278: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p278
# Scraping page 279: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p279
# Scraping page 280: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p280
# Scraping page 281: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p281
# Scraping page 282: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p282
# Scraping page 283: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p283
# Scraping page 284: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p284
# Scraping page 285: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p285
# Scraping page 286: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p286
# Scraping page 287: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p287
# Scraping page 288: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p288
# Scraping page 289: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p289
# Scraping page 290: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p290
# Scraping page 291: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p291
# Scraping page 292: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p292
# Scraping page 293: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p293
# Scraping page 294: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p294
# Scraping page 295: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p295
# Scraping page 296: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p296
# Scraping page 297: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p297
# Scraping page 298: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p298
# Scraping page 299: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p299
# Scraping page 300: https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p300
# 15001

# %% [markdown]
# ## Task A

# %%
# Importing Data
messagedf = pd.read_csv("messagedata.csv")
messagedf['Message'] = messagedf['Message'].fillna('')

# Counting Number of Words and Sorting
words = ' '.join(messagedf['Message']).lower().split()
word_counts = Counter(words)
sorted_word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)
sorted_word_counts_100 = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)[:100]

# All Words

# Finding Ranks and Frequencies
ranks = np.arange(1, len(sorted_word_counts) + 1)
frequencies = np.array([count for word, count in sorted_word_counts])

# Log Transformations
log_ranks = np.log(ranks)
log_frequencies = np.log(frequencies)

# Econometric Regression
X = sm.add_constant(log_ranks)
model = sm.OLS(log_frequencies, X)
results = model.fit()

# Graphing Results 
zipf_line = log_frequencies[0] + (-1) * (log_ranks - log_ranks[0])

plt.scatter(log_ranks, log_frequencies, color='blue', label='Log-Log Data')
plt.plot(log_ranks, results.predict(X), color='red', label=f'Regression Line (Slope: {results.params[1]:.2f})')
plt.plot(log_ranks, zipf_line, color='green', linestyle='--', label='Slope = -1 (Zipf\'s Law)')
plt.xlabel('Log Rank')
plt.ylabel('Log Frequency')
plt.title('Zipf\'s Law - Log-Log Plot for All Words')
plt.legend()
plt.show()

# Top 100

# Finding Ranks and Frequencies
ranks_100 = np.arange(1, len(sorted_word_counts_100) + 1)
frequencies_100 = np.array([count for word, count in sorted_word_counts_100])

# Log Transformations
log_ranks_100 = np.log(ranks_100)
log_frequencies_100 = np.log(frequencies_100)

# Econometric Regression
X_100 = sm.add_constant(log_ranks_100)
model_100 = sm.OLS(log_frequencies_100, X_100)
results_100 = model_100.fit()

# Graphing Results 
zipf_line_100 = log_frequencies_100[0] + (-1) * (log_ranks_100 - log_ranks_100[0])

plt.scatter(log_ranks_100, log_frequencies_100, color='blue', label='Log-Log Data')
plt.plot(log_ranks_100, results_100.predict(X_100), color='red', label=f'Regression Line (Slope: {results_100.params[1]:.2f})')
plt.plot(log_ranks_100, zipf_line_100, color='green', linestyle='--', label='Slope = -1 (Zipf\'s Law)')
plt.xlabel('Log Rank')
plt.ylabel('Log Frequency')
plt.title('Zipf\'s Law - Log-Log Plot for Top 100 Words')
plt.legend()
plt.show()
# Out:
# [('the', 78036),
#  ('a', 38720),
#  ('and', 30863),
#  ('to', 30788),
#  ('i', 27593),
#  ('is', 22176),
#  ('of', 21531),
#  ('in', 19456),
#  ('that', 16776),
#  ('for', 14487),
#  ('it', 14423),
#  ('you', 13698),
#  ('with', 11640),
#  ('on', 10293),
#  ('but', 9443),
#  ('not', 9271),
#  ('my', 9142),
#  ('have', 9050),
#  ('are', 8807),
#  ('as', 8407),
#  ('car', 8047),
#  ('be', 7700),
#  ('was', 6917),
#  ('or', 6445),
#  ('they', 6377),
#  ('at', 6075),
#  ('if', 5901),
#  ('this', 5328),
#  ('an', 5179),
#  ('like', 5111),
#  ('more', 4810),
#  ('about', 4740),
#  ('than', 4697),
#  ('would', 4551),
#  ('bmw', 4510),
#  ('has', 4471),
#  ('-', 4450),
#  ('just', 4446),
#  ('all', 4276),
#  ('will', 4105),
#  ('one', 4065),
#  ('so', 4025),
#  ('get', 4022),
#  ("it's", 4021),
#  ('can', 4017),
#  ('your', 3952),
#  ('cars', 3869),
#  ('what', 3862),
#  ('from', 3635),
#  ("don't", 3388),
#  ('think', 3253),
#  ('out', 3240),
#  ('me', 3174),
#  ('when', 3146),
#  ('do', 3124),
#  ('had', 2986),
#  ('no', 2972),
#  ('new', 2946),
#  ('tl', 2773),
#  ('some', 2764),
#  ('up', 2723),
#  ('there', 2664),
#  ('their', 2637),
#  ('even', 2601),
#  ('only', 2528),
#  ('by', 2439),
#  ('much', 2418),
#  ("i'm", 2392),
#  ('any', 2354),
#  ('we', 2314),
#  ('better', 2310),
#  ('3', 2299),
#  ('other', 2210),
#  ('very', 2179),
#  ('good', 2176),
#  ('over', 2170),
#  ('drive', 2166),
#  ('people', 2118),
#  ('how', 2095),
#  ('its', 2046),
#  ('really', 2043),
#  ('then', 2024),
#  ('know', 1962),
#  ('which', 1941),
#  ('same', 1936),
#  ('because', 1880),
#  ('want', 1848),
#  ('most', 1808),
#  ('driving', 1776),
#  ('also', 1763),
#  ('were', 1753),
#  ('who', 1738),
#  ('still', 1732),
#  ('been', 1703),
#  ('performance', 1694),
#  ('see', 1659),
#  ('make', 1647),
#  ('could', 1632),
#  ('luxury', 1576),
#  ('g35', 1574)]

# %% [markdown]
# ## Task B

# %%
# ChatGPT Support
# Set up ChromeDriver path
driver_path = "/Users/ramzikattan/Downloads/chromedriver-mac-arm64/chromedriver"
chrome_path = "/Applications/Google Chrome.app/Contents/MacOS/Google Chrome"

# Configure Chrome options
chrome_options = Options()
chrome_options.binary_location = chrome_path

# Set up the Chrome WebDriver service
service = Service(driver_path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# Open the webpage
carurl = "https://www.kbb.com/car-make-model-list/used/view-all/make/"
driver.get(carurl)
time.sleep(5)  # Wait for the page to load

# Parse the page with BeautifulSoup
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# Close the browser after fetching the page
driver.quit()

# Find all table rows
rows = soup.find_all("tr")
print(f"Number of rows fetched: {len(rows)}")

make_model_data = []

# Loop through each row and extract make, model, and years
for row in rows:
    tds = row.find_all("td", class_="css-irk93x ee33uo33")
    
    # Check if the expected number of <td> elements exist
    if len(tds) >= 3:
        try:
            # Extract model from the second <td>
            model_td = tds[0]
            model = model_td.find("div", class_="css-z687n ee33uo36").get_text(strip=True)
            
            # Extract make from the third <td>
            make_td = tds[1]
            make = make_td.find("div", class_="css-z687n ee33uo36").get_text(strip=True)
            
            # Append the extracted data
            make_model_data.append({
                "make": make,
                "model": model,
            })
        except Exception as e:
            print(f"Error parsing row: {e}")

makemodeldf = pd.DataFrame(make_model_data)
makemodeldf.to_csv("make_model_data.csv")
# Out:
# Number of rows fetched: 1417

# %%
# Merging the two dataframes to account for most car brands
makemodeldf['make'] = makemodeldf['make'].str.lower()
makemodeldf['model'] = makemodeldf['model'].str.lower()
print(len(makemodeldf))

makemodeldf2 = pd.read_csv("Replacement_words.csv")
makemodeldf2.rename(columns={'Brand': 'make'}, inplace=True)
makemodeldf2.rename(columns={'Model': 'model'}, inplace=True)
makemodeldf2['make'] = makemodeldf2['make'].str.lower()
makemodeldf2['model'] = makemodeldf2['model'].str.lower()
print(len(makemodeldf2))

# Save to CSV
mergedmakemodel = pd.concat([makemodeldf, makemodeldf2], ignore_index=True)
mergedmakemodel = mergedmakemodel.drop_duplicates()
mergedmakemodel.to_csv("merged.csv")
print(len(mergedmakemodel))
# Out:
# 1416
# 539
# 1730

# %%
stop_words = set(stopwords.words('english'))
model_to_brand = dict(zip(mergedmakemodel['model'].str.lower(), mergedmakemodel['make'].str.lower()))
brands_set = set(model_to_brand.values())

def replacements(message, model_to_brand, brands_set):
    words = re.findall(r'\w+', message.lower())
    replaced_words = [model_to_brand.get(word, word) for word in words]

    # Create a new message with replaced words
    new_message = ' '.join(replaced_words)

    # Filter the replaced words for the list
    filtered_brands = set([word for word in replaced_words if word not in stop_words and word in brands_set])

    return filtered_brands, new_message 

messages = messagedf['Message']
brand_counter = Counter()

for message in messages:
    brands, new_message = replacements(message, model_to_brand, brands_set)
    brand_counter.update(brands)

brands_to_remove = ['car', 'sedan', 'problem', 'seat', 'mini']

for brand in brands_to_remove:
    brand_counter.pop(brand, None)

top_10 = brand_counter.most_common(10)

print("Top 10 Brands by Frequency:")
for brand, count in top_10:
    print(f"{brand.capitalize()}: {count}")
# Out:
# Top 10 Brands by Frequency:
# Infiniti: 11162
# Lexus: 9380
# Bmw: 5111
# Acura: 3232
# Polestar: 2365
# Audi: 2234
# Honda: 1691
# Cadillac: 1319
# Toyota: 1000
# Nissan: 835

# %% [markdown]
# ## Task C

# %%
import itertools
import pandas as pd
from collections import Counter
import re

top_10_brands = [brand for brand, count in top_10]

def find_co_occurrences(message, top_10_brands, distance=7):
    words = message.split()
    found_brands = []
    
    for i, word in enumerate(words):
        if word in top_10_brands:
            found_brands.append((word, i)) 
    
    co_occurrences = set()
    for (brand1, idx1), (brand2, idx2) in itertools.combinations(found_brands, 2):
        if abs(idx1 - idx2) <= distance:  # Check distance in terms of word indices
            co_occurrences.add(tuple(sorted((brand1, brand2))))  # Use sorted tuple for co-occurrence
    
    return co_occurrences

brand_counter = Counter()
co_occurrence_counter = Counter()

total_messages = len(messagedf)

# Loop through all messages to update counters
for message in messagedf['Message']:
    filtered_brands, replaced_message = replacements(message, model_to_brand, brands_set)
    # Update brand counter with the filtered brands
    brand_counter.update(filtered_brands)
    
    # Now find co-occurrences using the replaced message
    co_occurrences = find_co_occurrences(replaced_message, top_10_brands, distance=10)
    co_occurrence_counter.update(co_occurrences)

    
def calculate_lift(brand1, brand2, brand_counter, co_occurrence_counter, total_messages):
    P_A = brand_counter[brand1] / total_messages 
    P_B = brand_counter[brand2] / total_messages  
    
    # Combine counts for both (brand1, brand2) and (brand2, brand1)
    P_AB = (co_occurrence_counter[(brand1, brand2)] + co_occurrence_counter[(brand2, brand1)]) / total_messages #if (brand1, brand2) in co_occurrence_counter or (brand2, brand1) in co_occurrence_counter else 0
    
    if P_A * P_B == 0: 
        return 0
    return P_AB / (P_A * P_B)

lift_results = []
for (brand1, brand2) in itertools.combinations(top_10_brands, 2):
    lift = calculate_lift(brand1, brand2, brand_counter, co_occurrence_counter, total_messages)
    lift_results.append((brand1, brand2, lift))

lift_df = pd.DataFrame(lift_results, columns=['Brand1', 'Brand2', 'Lift'])
lift_df.sort_values(by='Lift', ascending=False, inplace=True)

lift_matrix = lift_df.pivot(index='Brand1', columns='Brand2', values='Lift')
lift_matrix = lift_matrix.combine_first(lift_matrix.T)
lift_matrix.fillna(0, inplace=True)

lift_df.to_csv('brand_lift_ratios.csv', index=False)
print(lift_matrix)

def replacements(message, model_to_brand, brands_set):
    words = re.findall(r'\w+', message.lower())
    replaced_words = [model_to_brand.get(word, word) for word in words]

    # Create a new message with replaced words
    new_message = ' '.join(replaced_words)

    # Filter the replaced words for the list
    filtered_brands = set([word for word in replaced_words if word not in stop_words and word in brands_set])
    return filtered_brands, new_message
print(co_occurrence_counter['acura', 'nissan'])
print(co_occurrence_counter['nissan', 'acura'])
print("\n\n")
print(brand_counter)
print("\n\n")
print(co_occurrence_counter)
print("\n\n" + replaced_message + "\n\n")
# Out:
#              acura      audi       bmw  cadillac     honda  infiniti     lexus    nissan  polestar    toyota
# acura     0.000000  0.806116  0.525801  0.668587  1.177504  0.868235  0.820409  0.528063  0.516147  0.385236
# audi      0.806116  0.000000  0.773832  0.814540  0.357385  0.752579  0.657885  0.257336  1.016457  0.261880
# bmw       0.525801  0.773832  0.000000  0.647534  0.300273  0.775175  0.732822  0.288232  0.536126  0.381555
# cadillac  0.668587  0.814540  0.647534  0.000000  0.195043  0.781500  0.750522  0.136204  0.495315  0.272952
# honda     1.177504  0.357385  0.300273  0.195043  0.000000  0.633422  0.540020  1.328006  0.390103  2.075833
# infiniti  0.868235  0.752579  0.775175  0.781500  0.633422  0.000000  0.754208  0.783828  0.626791  0.532198
# lexus     0.820409  0.657885  0.732822  0.750522  0.540020  0.754208  0.000000  0.589904  0.503782  0.626907
# nissan    0.528063  0.257336  0.288232  0.136204  1.328006  0.783828  0.589904  0.000000  0.243082  1.868388
# polestar  0.516147  1.016457  0.536126  0.495315  0.390103  0.626791  0.503782  0.243082  0.000000  0.260060
# toyota    0.385236  0.261880  0.381555  0.272952  2.075833  0.532198  0.626907  1.868388  0.260060  0.000000
# 95
# 0
#
#
#
# Counter({'infiniti': 11162, 'lexus': 9380, 'car': 7308, 'bmw': 5111, 'acura': 3232, 'polestar': 2365, 'audi': 2234, 'sedan': 1766, 'honda': 1691, 'cadillac': 1319, 'toyota': 1000, 'seat': 911, 'nissan': 835, 'problem': 809, 'mini': 772, 'chrysler': 639, 'porsche': 590, 'ford': 559, 'volkswagen': 554, 'volvo': 538, 'mercedes-benz': 512, 'chevrolet': 396, 'subaru': 372, 'hyundai': 366, 'lincoln': 335, 'saab': 311, 'fiat': 283, 'daihatsu': 274, 'mazda': 264, 'buick': 253, 'dodge': 194, 'mclaren': 167, 'pontiac': 166, 'ferrari': 155, 'mercedes': 133, 'lucid': 127, 'volkwagen': 108, 'kia': 108, 'jaguar': 104, 'scion': 93, 'oldsmobile': 87, 'smart': 74, 'mitsubishi': 68, 'saturn': 65, 'maybach': 46, 'jeep': 44, 'suzuki': 42, 'hummer': 38, 'plymouth': 37, 'eagle': 36, 'lotus': 36, 'srt': 32, 'mercury': 32, 'geo': 31, 'maserati': 25, 'bentley': 23, 'lamborghini': 23, 'isuzu': 21, 'tesla': 17, 'gmc': 14, 'fisker': 12, 'alfa romeo': 11, 'rolls-royce': 8, 'aston martin': 8, 'daewoo': 7, 'land rover': 7, 'kia.': 7, 'freightliner': 1})
#
#
#
# Counter({('infiniti', 'infiniti'): 5879, ('infiniti', 'lexus'): 5264, ('bmw', 'infiniti'): 2948, ('lexus', 'lexus'): 2837, ('bmw', 'lexus'): 2342, ('acura', 'infiniti'): 2088, ('acura', 'lexus'): 1658, ('audi', 'infiniti'): 1251, ('infiniti', 'polestar'): 1103, ('bmw', 'bmw'): 1098, ('acura', 'acura'): 1051, ('audi', 'lexus'): 919, ('honda', 'infiniti'): 797, ('cadillac', 'infiniti'): 767, ('lexus', 'polestar'): 745, ('audi', 'audi'): 623, ('cadillac', 'lexus'): 619, ('audi', 'bmw'): 589, ('acura', 'bmw'): 579, ('honda', 'lexus'): 571, ('infiniti', 'nissan'): 487, ('polestar', 'polestar'): 454, ('bmw', 'polestar'): 432, ('acura', 'honda'): 429, ('infiniti', 'toyota'): 396, ('lexus', 'toyota'): 392, ('acura', 'audi'): 388, ('audi', 'polestar'): 358, ('honda', 'honda'): 332, ('lexus', 'nissan'): 308, ('cadillac', 'cadillac'): 304, ('bmw', 'cadillac'): 291, ('acura', 'polestar'): 263, ('honda', 'toyota'): 234, ('acura', 'cadillac'): 190, ('nissan', 'nissan'): 185, ('bmw', 'honda'): 173, ('audi', 'cadillac'): 160, ('toyota', 'toyota'): 144, ('bmw', 'toyota'): 130, ('honda', 'nissan'): 125, ('nissan', 'toyota'): 104, ('honda', 'polestar'): 104, ('cadillac', 'polestar'): 103, ('acura', 'nissan'): 95, ('audi', 'honda'): 90, ('acura', 'toyota'): 83, ('bmw', 'nissan'): 82, ('polestar', 'toyota'): 41, ('audi', 'toyota'): 39, ('audi', 'nissan'): 32, ('nissan', 'polestar'): 32, ('cadillac', 'honda'): 29, ('cadillac', 'toyota'): 24, ('cadillac', 'nissan'): 10})
#
#
# probably sween its right in his backyard the nyc auto show

# %% [markdown]
# ## Task D

# %%
dissimilarity_matrix = 1 / (lift_matrix + 1e-10)
np.fill_diagonal(dissimilarity_matrix.values, 0)  # Set diagonal to zero

# Multidimensional Scaling (MDS)
seed = np.random.RandomState(seed=3)
mds = manifold.MDS(n_components=2, max_iter=3000, eps=1e-9, 
                   random_state=seed, dissimilarity="precomputed")

try:
    results = mds.fit(dissimilarity_matrix)
    coords = results.embedding_
    
except ValueError as e:
    print(f"Error during MDS fitting: {e}")
    coords = np.zeros((len(lift_matrix), 2))  # Placeholder in case of error

# Plotting the MDS results
plt.figure(figsize=(10, 8))
plt.scatter(coords[:, 0], coords[:, 1], marker='o')

# Annotate each point with the corresponding brand name
for label, x, y in zip(lift_matrix.index, coords[:, 0], coords[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(-20, 20),
                 textcoords='offset points', ha='left', va='bottom',
                 bbox=dict(boxstyle='round,pad=0.5', fc='orange', alpha=0.5),
                 arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0'))

# Left-align the title
plt.title('MDS Plot Based on Lift Values', loc='right')
plt.xlabel('MDS Dimension 1')
plt.ylabel('MDS Dimension 2')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Task E

# %% [markdown]
# ## Task F

# %%
import itertools
import pandas as pd
from collections import Counter
import re

top_10_brands = [brand for brand, count in top_10]
attributes = ['performance', 'luxury', 'interior', 'rwd', 'awd', 'power', 'cost', 'hp', 'handling']

def find_co_occurrences(message, top_10_brands, attributes):
    words = message.split()
    found_brands = []
    found_attributes = []

    for word in words:
        if word in top_10_brands:
            found_brands.append(word)
        if word in attributes:
            found_attributes.append(word)
    
    co_occurrences = set()
    for brand in found_brands:
        for attribute in found_attributes:
            co_occurrences.add((brand, attribute))  # No distance check, just record co-occurrences
    
    return co_occurrences

brand_counter = Counter()
attribute_counter = Counter()  # Counter for attributes
co_occurrence_counter = Counter()

total_messages = len(messagedf)

# Loop through all messages to update counters
for message in messagedf['Message']:
    filtered_brands, replaced_message = replacements(message, model_to_brand, brands_set)
    
    # Update brand counter with the filtered brands
    brand_counter.update(filtered_brands)
    
    # Count attributes in the message
    for word in replaced_message.split():
        if word in attributes:
            attribute_counter[word] += 1
    
    # Find co-occurrences with attributes
    co_occurrences = find_co_occurrences(replaced_message, top_10_brands, attributes)
    co_occurrence_counter.update(co_occurrences)

def calculate_lift(brand, attribute, brand_counter, attribute_counter, co_occurrence_counter, total_messages):
    P_A = brand_counter[brand] / total_messages 
    P_B = attribute_counter[attribute] / total_messages if attribute in attribute_counter else 0
    P_AB = co_occurrence_counter[(brand, attribute)] / total_messages if (brand, attribute) in co_occurrence_counter else 0
    
    if P_A * P_B == 0: 
        return 0
    return P_AB / (P_A * P_B)

# Create a DataFrame for lifts
lift_results = []

for brand in top_10_brands:
    for attribute in attributes:
        lift = calculate_lift(brand, attribute, brand_counter, attribute_counter, co_occurrence_counter, total_messages)
        lift_results.append((brand, attribute, lift))

# Create a DataFrame with brands as rows and attributes as columns
lift_df = pd.DataFrame(lift_results, columns=['Brand', 'Attribute', 'Lift'])

# Pivot the DataFrame to have brands in rows and attributes in columns
final_lift_matrix = lift_df.pivot(index='Brand', columns='Attribute', values='Lift')

# Fill any NaN values with 0
final_lift_matrix.fillna(0, inplace=True)

# Save to CSV if needed
final_lift_matrix.to_csv('brand_attribute_lift_ratios.csv', index=True)

# Print the final lift matrix
print(final_lift_matrix)
# Out:
# Attribute       awd      cost  handling        hp  interior    luxury  performance     power       rwd
# Brand
# acura      1.211531  0.953100  1.358458  1.031422  1.149388  1.050638     1.068455  1.234257  1.127784
# audi       1.310514  1.292701  1.406224  1.128097  1.345691  1.050859     1.099397  1.518328  0.907548
# bmw        0.659719  1.308997  1.266339  1.095749  0.918934  0.899515     1.064660  1.152051  0.752186
# cadillac   0.597856  1.204201  1.272170  1.061481  1.573190  1.186565     1.092033  1.032264  0.739162
# honda      0.921949  1.176486  1.454887  1.088186  1.209149  1.264346     1.157572  1.454970  1.048282
# infiniti   0.675622  0.879666  0.932503  0.766939  0.826130  0.734876     0.812317  0.911650  0.730529
# lexus      0.748895  1.007444  1.055857  0.874259  0.897827  0.879701     0.932515  1.024999  0.832699
# nissan     0.868412  1.152852  1.178546  1.229623  0.969785  1.029217     1.046807  1.516177  1.141073
# polestar   1.042461  1.689183  1.168292  1.336241  1.074273  0.847889     1.087952  1.595830  1.072768
# toyota     0.652611  1.363727  1.690609  0.693380  1.103312  1.669883     1.218793  1.027139  0.930638

# %%
word_counts = [word for word in sorted_word_counts if word not in stop_words]
word_counts
# Out:
# [('the', 78036),
#  ('a', 38720),
#  ('and', 30863),
#  ('to', 30788),
#  ('i', 27593),
#  ('is', 22176),
#  ('of', 21531),
#  ('in', 19456),
#  ('that', 16776),
#  ('for', 14487),
#  ('it', 14423),
#  ('you', 13698),
#  ('with', 11640),
#  ('on', 10293),
#  ('but', 9443),
#  ('not', 9271),
#  ('my', 9142),
#  ('have', 9050),
#  ('are', 8807),
#  ('as', 8407),
#  ('car', 8047),
#  ('be', 7700),
#  ('was', 6917),
#  ('or', 6445),
#  ('they', 6377),
#  ('at', 6075),
#  ('if', 5901),
#  ('this', 5328),
#  ('an', 5179),
#  ('like', 5111),
#  ('more', 4810),
#  ('about', 4740),
#  ('than', 4697),
#  ('would', 4551),
#  ('bmw', 4510),
#  ('has', 4471),
#  ('-', 4450),
#  ('just', 4446),
#  ('all', 4276),
#  ('will', 4105),
#  ('one', 4065),
#  ('so', 4025),
#  ('get', 4022),
#  ("it's", 4021),
#  ('can', 4017),
#  ('your', 3952),
#  ('cars', 3869),
#  ('what', 3862),
#  ('from', 3635),
#  ("don't", 3388),
#  ('think', 3253),
#  ('out', 3240),
#  ('me', 3174),
#  ('when', 3146),
#  ('do', 3124),
#  ('had', 2986),
#  ('no', 2972),
#  ('new', 2946),
#  ('tl', 2773),
#  ('some', 2764),
#  ('up', 2723),
#  ('there', 2664),
#  ('their', 2637),
#  ('even', 2601),
#  ('only', 2528),
#  ('by', 2439),
#  ('much', 2418),
#  ("i'm", 2392),
#  ('any', 2354),
#  ('we', 2314),
#  ('better', 2310),
#  ('3', 2299),
#  ('other', 2210),
#  ('very', 2179),
#  ('good', 2176),
#  ('over', 2170),
#  ('drive', 2166),
#  ('people', 2118),
#  ('how', 2095),
#  ('its', 2046),
#  ('really', 2043),
#  ('then', 2024),
#  ('know', 1962),
#  ('which', 1941),
#  ('same', 1936),
#  ('because', 1880),
#  ('want', 1848),
#  ('most', 1808),
#  ('driving', 1776),
#  ('also', 1763),
#  ('were', 1753),
#  ('who', 1738),
#  ('still', 1732),
#  ('been', 1703),
#  ('performance', 1694),
#  ('see', 1659),
#  ('make', 1647),
#  ('could', 1632),
#  ('luxury', 1576),
#  ('g35', 1574),
#  ("that's", 1539),
#  ('acura', 1519),
#  ('those', 1514),
#  ('does', 1513),
#  ('buy', 1511),
#  ('too', 1509),
#  ('am', 1505),
#  ('why', 1492),
#  ('price', 1489),
#  ('lexus', 1487),
#  ('back', 1474),
#  ('say', 1469),
#  ('them', 1445),
#  ('going', 1444),
#  ('these', 1430),
#  ('should', 1427),
#  ('many', 1409),
#  ('go', 1393),
#  ('time', 1377),
#  ('well', 1372),
#  ('way', 1336),
#  ('did', 1324),
#  ("i've", 1313),
#  ('great', 1298),
#  ('into', 1289),
#  ('series', 1259),
#  ('now', 1249),
#  ('years', 1243),
#  ('manual', 1243),
#  ('got', 1236),
#  ('never', 1217),
#  ('less', 1209),
#  ('take', 1207),
#  ('he', 1199),
#  ('best', 1188),
#  ('engine', 1184),
#  ('&', 1162),
#  ('audi', 1159),
#  ("doesn't", 1150),
#  ('may', 1150),
#  ('here', 1140),
#  ('it.', 1133),
#  ('look', 1131),
#  ('sport', 1129),
#  ('sedan', 1125),
#  ('car.', 1104),
#  ('interior', 1101),
#  ('both', 1094),
#  ("can't", 1093),
#  ('need', 1093),
#  ('infiniti', 1092),
#  ('cts', 1089),
#  ('being', 1070),
#  ('test', 1064),
#  ('little', 1063),
#  ('since', 1060),
#  ('lot', 1046),
#  ('few', 1027),
#  ('every', 1024),
#  ('off', 1019),
#  ('--', 1019),
#  ('after', 1012),
#  ('two', 1011),
#  ('while', 999),
#  ('looking', 994),
#  ('rwd', 988),
#  ('sure', 979),
#  ('last', 978),
#  ("didn't", 976),
#  ('something', 975),
#  ('awd', 972),
#  ("i'd", 970),
#  ('where', 963),
#  ('first', 963),
#  ('around', 946),
#  ('right', 934),
#  ('probably', 920),
#  ('feel', 919),
#  ('power', 909),
#  ('down', 904),
#  ('own', 895),
#  ('said', 887),
#  ('pretty', 876),
#  ('getting', 876),
#  ('find', 868),
#  ('year', 865),
#  ('nice', 858),
#  ('different', 858),
#  ('car,', 851),
#  ('another', 847),
#  ('fwd', 846),
#  ('used', 843),
#  ('g', 840),
#  ('agree', 840),
#  ('miles', 821),
#  ('tsx', 815),
#  ('big', 806),
#  ('might', 805),
#  ('long', 801),
#  ('thing', 800),
#  ('actually', 800),
#  ('5', 800),
#  ("isn't", 797),
#  ('drove', 793),
#  ('put', 790),
#  ('maybe', 789),
#  ('point', 787),
#  ('dealer', 779),
#  ('us', 774),
#  ('far', 773),
#  ('2', 769),
#  ('makes', 761),
#  ('between', 760),
#  ('cost', 754),
#  ('made', 752),
#  ('without', 751),
#  ('sales', 747),
#  ('hp', 737),
#  ('least', 736),
#  ('always', 731),
#  ('old', 729),
#  ('a4', 725),
#  ('seems', 724),
#  ('next', 719),
#  ('believe', 717),
#  ('4', 713),
#  ("i'll", 713),
#  ('before', 713),
#  ('come', 701),
#  ('keep', 700),
#  ('ever', 695),
#  ("you're", 695),
#  ('looks', 692),
#  ('driven', 691),
#  ('handling', 690),
#  ('6', 688),
#  ('real', 688),
#  ('love', 687),
#  ('his', 684),
#  ('335i', 681),
#  ('almost', 678),
#  ('bought', 664),
#  ('use', 663),
#  ('class', 653),
#  ('top', 651),
#  ('high', 649),
#  ('tires', 646),
#  ('guess', 641),
#  ('sports', 640),
#  ('our', 637),
#  ('value', 637),
#  ('330i', 633),
#  ('front', 633),
#  ('auto', 632),
#  ('give', 631),
#  ('lease', 624),
#  ('bit', 623),
#  ('difference', 620),
#  ('current', 616),
#  ('it,', 609),
#  ('comes', 605),
#  ('read', 604),
#  ('nothing', 604),
#  ('enough', 601),
#  ('however,', 601),
#  ('quite', 596),
#  ('hard', 593),
#  ('speed', 593),
#  ('torque', 591),
#  ('rear', 591),
#  ('under', 588),
#  ('anything', 582),
#  ('pay', 579),
#  ('based', 577),
#  ('.', 576),
#  ('vehicle', 575),
#  ('money', 569),
#  ('model', 566),
#  ('cars.', 563),
#  ('bad', 562),
#  ('package', 558),
#  ('me.', 552),
#  ('having', 551),
#  ('road', 550),
#  ('end', 549),
#  ('fact', 543),
#  ('things', 541),
#  ('buying', 539),
#  ('honda', 536),
#  ('thought', 535),
#  ('gas', 527),
#  ('such', 526),
#  ('talking', 526),
#  ('fun', 524),
#  ('level', 523),
#  ('seat', 522),
#  ('tell', 512),
#  ('anyone', 512),
#  ('compared', 510),
#  ('through', 503),
#  ('either', 500),
#  ('coupe', 493),
#  ('mb', 491),
#  ('someone', 487),
#  ("wouldn't", 486),
#  ('mean', 484),
#  ('close', 476),
#  ('entry', 475),
#  ('transmission', 474),
#  ('me,', 474),
#  ('trying', 473),
#  ('vehicles', 471),
#  ('market', 470),
#  ('well,', 470),
#  ('quality', 469),
#  ('base', 468),
#  ('couple', 467),
#  ('each', 465),
#  ('reason', 463),
#  ('steering', 460),
#  ('brand', 459),
#  ('post', 458),
#  ('others', 455),
#  ('sell', 454),
#  ('automatic', 453),
#  ('work', 449),
#  ('gm', 448),
#  ('she', 447),
#  ('seats', 444),
#  ("won't", 442),
#  ('line', 441),
#  ('experience', 441),
#  ('gets', 441),
#  ('ellps', 440),
#  ('is350', 438),
#  ('problem', 437),
#  ('small', 437),
#  ('care', 435),
#  ('consider', 435),
#  ('accord', 435),
#  ('add', 432),
#  ('cars,', 432),
#  ('though', 430),
#  ('worth', 430),
#  ('came', 430),
#  ('bmw,', 428),
#  ('weight', 428),
#  ('until', 427),
#  ('low', 427),
#  ('turbo', 427),
#  ('volvo', 424),
#  ('once', 424),
#  ('try', 423),
#  ('japanese', 423),
#  ('premium', 423),
#  ('seem', 419),
#  ('higher', 419),
#  ('part', 418),
#  ('must', 417),
#  ('(and', 415),
#  ('dont', 414),
#  ('went', 412),
#  ('day', 408),
#  ('reliability', 407),
#  ('standard', 407),
#  ('let', 403),
#  ('wanted', 401),
#  ('snow', 400),
#  ('found', 399),
#  ('cadillac', 399),
#  ('msrp', 399),
#  ('mercedes', 398),
#  ('rather', 398),
#  ('nissan', 398),
#  ('deal', 398),
#  ('saying', 398),
#  ('able', 398),
#  ('yet', 397),
#  ('leather', 396),
#  ('seen', 396),
#  ('live', 395),
#  ('offer', 394),
#  ('extra', 393),
#  ('vs.', 393),
#  ('doing', 392),
#  ('system', 391),
#  ('expensive', 389),
#  ('german', 388),
#  ('sold', 387),
#  ('wheel', 386),
#  ('v6', 384),
#  ("there's", 382),
#  ('m3', 381),
#  ('else', 381),
#  ('second', 379),
#  ('is,', 378),
#  ('especially', 378),
#  ('given', 376),
#  ('mpg', 374),
#  ('mileage', 372),
#  ('fuel', 372),
#  ('numbers', 371),
#  ('options', 369),
#  ("bmw's", 367),
#  ('yes,', 365),
#  ('again', 364),
#  ('stick', 364),
#  ('size', 364),
#  ('3-series', 363),
#  ('driver', 363),
#  ('tl,', 363),
#  ('service', 361),
#  ('track', 361),
#  ('done', 360),
#  ('change', 359),
#  ('making', 357),
#  ('true', 355),
#  ('set', 355),
#  ('everything', 355),
#  ('felt', 354),
#  ('ride', 352),
#  ('certainly', 350),
#  ('list', 349),
#  ('=', 349),
#  ('simply', 347),
#  ('near', 347),
#  ("wasn't", 347),
#  ("they're", 346),
#  ('etc.', 344),
#  ('wife', 344),
#  ('world', 343),
#  ('kind', 342),
#  ('similar', 339),
#  ('vs', 338),
#  ('three', 337),
#  ('order', 337),
#  ('available', 336),
#  ('definitely', 336),
#  ('run', 336),
#  ('oil', 335),
#  ('compare', 334),
#  ('that,', 334),
#  ('1', 334),
#  ('wheels', 334),
#  ('understand', 333),
#  ('0-60', 332),
#  ('said,', 331),
#  ('already', 331),
#  ("aren't", 331),
#  ('sedans', 330),
#  ('fast', 330),
#  ('due', 330),
#  ('bmws', 330),
#  ('several', 329),
#  ('well.', 328),
#  ('porsche', 328),
#  ('regards,shipo', 326),
#  ('matter', 325),
#  ('problems', 325),
#  ('number', 323),
#  ('tl.', 322),
#  ('unless', 322),
#  ("haven't", 321),
#  ('option', 321),
#  ('per', 321),
#  ('took', 320),
#  ('suspension', 319),
#  ('above', 318),
#  ('winter', 318),
#  ('times', 315),
#  ('american', 314),
#  ('owned', 314),
#  ('owners', 313),
#  ('(or', 313),
#  ('that.', 312),
#  ('course', 312),
#  ('away', 310),
#  ('faster', 309),
#  ('maintenance', 309),
#  ('models', 308),
#  ('them.', 307),
#  ('10', 306),
#  ('left', 306),
#  ('coming', 305),
#  ('months', 304),
#  ('choice', 304),
#  ('interesting', 303),
#  ('her', 302),
#  ('mph', 302),
#  ('fit', 302),
#  ('check', 299),
#  ('against', 299),
#  ('side', 299),
#  ('looked', 298),
#  ('type', 297),
#  ('one.', 297),
#  ('warranty', 297),
#  ('but,', 295),
#  ('costs', 295),
#  ('everyone', 294),
#  ('call', 294),
#  ('needs', 293),
#  ('hope', 293),
#  ('wrong', 293),
#  ('saab', 293),
#  ('328i', 293),
#  ('plus', 292),
#  ('sound', 292),
#  ('start', 291),
#  ('toyota', 291),
#  ('loaded', 291),
#  ('talk', 288),
#  ('remember', 288),
#  ('average', 287),
#  ('lower', 286),
#  ('comparison', 284),
#  ('features', 284),
#  ('whole', 283),
#  ('dealers', 283),
#  ('exactly', 282),
#  ('e90', 281),
#  ('previous', 280),
#  ('opinion', 277),
#  ('vw', 277),
#  ("couldn't", 275),
#  ('drives', 275),
#  ('considered', 274),
#  ('discussion', 272),
#  ('prefer', 271),
#  ('bmw.', 271),
#  ('too.', 270),
#  ('enjoy', 269),
#  ('smaller', 269),
#  ('place', 268),
#  ('again,', 267),
#  ('now,', 266),
#  ('(i', 266),
#  ('issue', 266),
#  ('free', 266),
#  ('selling', 265),
#  ('overall', 265),
#  ('"i', 265),
#  ('mind', 265),
#  ('guy', 265),
#  ('segment', 265),
#  ('comparing', 263),
#  ('bigger', 263),
#  ('maxima', 261),
#  ('heard', 261),
#  ('although', 261),
#  ('happy', 261),
#  ('version', 260),
#  ('drivers', 259),
#  ('so,', 259),
#  ('325i', 259),
#  ('goes', 258),
#  ('feels', 257),
#  ('issues', 257),
#  ('european', 257),
#  ('turn', 257),
#  ('show', 256),
#  ('personal', 256),
#  ('hit', 256),
#  ('g35,', 255),
#  ('hear', 254),
#  ('past', 254),
#  ('guys', 254),
#  ('pick', 254),
#  ('means', 254),
#  ('and,', 253),
#  ('saw', 253),
#  ('fine', 252),
#  ('g37', 252),
#  ('time.', 250),
#  ('called', 250),
#  ('equipped', 249),
#  ('spend', 249),
#  ('sedan.', 248),
#  ('highway', 248),
#  ('stop', 247),
#  ('c', 247),
#  ('diesel', 247),
#  ('sporty', 246),
#  ('person', 246),
#  ('330', 245),
#  ('styling', 245),
#  ('buyers', 245),
#  ('wants', 244),
#  ('liked', 244),
#  ('thanks', 244),
#  ('case', 244),
#  ('behind', 243),
#  ('days', 242),
#  ('you.', 242),
#  ('2004', 242),
#  ('built', 241),
#  ('design', 241),
#  ('important', 240),
#  ('here.', 240),
#  ('you,', 240),
#  ('engines', 240),
#  ("you'll", 239),
#  ('full', 239),
#  ('considering', 238),
#  ('move', 238),
#  ('6-speed', 237),
#  ('thinking', 237),
#  ('control', 237),
#  ('build', 237),
#  ('wait', 236),
#  ('paid', 236),
#  ('usually', 235),
#  ("let's", 235),
#  ('factor', 235),
#  ('prices', 233),
#  ('terms', 233),
#  ('m', 233),
#  ('is.', 232),
#  ('family', 232),
#  ('company', 232),
#  ('cheaper', 232),
#  ('a3', 232),
#  ('mentioned', 231),
#  ('instead', 231),
#  ('?', 231),
#  ('7', 231),
#  ('caddy', 230),
#  ('says', 229),
#  ('nearly', 228),
#  ('ed', 228),
#  ('body', 227),
#  (':p', 227),
#  ('lux', 226),
#  ('beat', 226),
#  ('certain', 226),
#  ('(which', 226),
#  ('s4', 225),
#  ('tire', 225),
#  ('question', 225),
#  ('course,', 225),
#  ('perhaps', 225),
#  ('please', 224),
#  ('taking', 223),
#  ('short', 223),
#  ('whether', 223),
#  ('folks', 222),
#  ('years.', 221),
#  ('dealership', 221),
#  ('afford', 221),
#  ('ago', 220),
#  ('handling,', 219),
#  ('huge', 219),
#  ('tranny', 219),
#  ('excellent', 218),
#  ('ford', 218),
#  ('years,', 218),
#  ('series,', 218),
#  ('using', 217),
#  ('except', 217),
#  ('door', 216),
#  ('performance,', 216),
#  ('way,', 216),
#  ('major', 216),
#  ('light', 216),
#  ('s', 215),
#  ('idea', 215),
#  ('brake', 215),
#  ('month', 215),
#  ('cts-v', 215),
#  ('expect', 213),
#  ('told', 213),
#  ("car's", 212),
#  ('during', 212),
#  ('reliable', 212),
#  ('"the', 212),
#  ('local', 212),
#  ('likely', 212),
#  ('60', 211),
#  ('posts', 211),
#  ('forum', 211),
#  ('911', 210),
#  ('including', 210),
#  ('335', 210),
#  ('doubt', 209),
#  ('rest', 209),
#  ('2007', 209),
#  ('lots', 208),
#  ('large', 207),
#  ('safety', 207),
#  ('longer', 206),
#  ('wonder', 206),
#  ('out.', 205),
#  ('head', 205),
#  ('help', 205),
#  ('him', 205),
#  ('lack', 205),
#  ('willing', 205),
#  ('camry', 204),
#  ('mention', 204),
#  ('mile', 204),
#  ("what's", 204),
#  ('is300', 203),
#  ('x-type', 203),
#  ('edmunds', 203),
#  ('paying', 202),
#  ('along', 201),
#  ('cannot', 201),
#  ('300', 201),
#  ('straight', 201),
#  ('choose', 200),
#  ('often', 200),
#  ("we're", 200),
#  ('engine,', 199),
#  ('shift', 199),
#  ('today', 199),
#  ('series.', 198),
#  ('2006', 198),
#  ('sounds', 197),
#  ('now.', 197),
#  ('total', 197),
#  ('serious', 195),
#  ('offers', 195),
#  ('myself', 195),
#  ('within', 195),
#  ('room', 194),
#  ('acceleration', 194),
#  ('added', 194),
#  ('purchase', 193),
#  ('completely', 193),
#  ('heavy', 192),
#  ('handles', 192),
#  ('easy', 191),
#  ('(the', 191),
#  ('according', 190),
#  ('gear', 190),
#  ('time,', 190),
#  ('328', 190),
#  ('lexus,', 189),
#  ('resale', 189),
#  ('one,', 189),
#  ('save', 188),
#  ('comments', 188),
#  ('mine', 188),
#  ('offered', 187),
#  ('inside', 187),
#  ('generation', 187),
#  ('e46', 187),
#  ('half', 186),
#  ('here,', 186),
#  ('ones', 186),
#  ('bimmer', 186),
#  ('nav', 186),
#  ('totally', 186),
#  ('handle', 186),
#  ('space', 185),
#  ('currently', 185),
#  ('sense', 185),
#  ('yes', 185),
#  ('2005', 185),
#  ('decent', 184),
#  ('takes', 184),
#  ('cts,', 184),
#  ('brakes', 184),
#  ('race', 184),
#  ('exterior', 183),
#  ('price.', 183),
#  ('fully', 183),
#  ('four', 183),
#  ('started', 183),
#  ('cheap', 182),
#  ('ask', 182),
#  ('none', 181),
#  ('reading', 181),
#  ('decided', 181),
#  ('friend', 181),
#  ('drive.', 180),
#  ('though.', 180),
#  ('posted', 179),
#  ('below', 179),
#  ('finally', 178),
#  ('smooth', 178),
#  ('perfect', 178),
#  ('class.', 177),
#  ('there.', 177),
#  ('larger', 177),
#  ('assume', 177),
#  ('better.', 176),
#  ('say,', 176),
#  ('original', 176),
#  ('home', 176),
#  ('audi,', 175),
#  ("you'd", 175),
#  ('priced', 174),
#  ('up.', 174),
#  ('however', 173),
#  ('powerful', 173),
#  ('play', 173),
#  ('trade', 173),
#  ('bottom', 172),
#  ('amount', 172),
#  ('cr', 172),
#  ('sh-awd', 172),
#  ('recent', 171),
#  ('manufacturers', 170),
#  ('lincoln', 170),
#  ('name', 170),
#  ('poor', 169),
#  ('also,', 169),
#  ('&#150;', 169),
#  ('hyundai', 169),
#  ('board', 169),
#  ('subaru', 169),
#  ('is250', 169),
#  ('easily', 168),
#  ('range', 168),
#  ('roads', 168),
#  ('grand', 168),
#  ('w/', 168),
#  ('price,', 167),
#  ('yeah,', 167),
#  ('parts', 167),
#  ('g35.', 167),
#  ('shop', 167),
#  ('2012', 167),
#  ('30', 166),
#  ('seats,', 166),
#  ('2011', 166),
#  ('europe', 165),
#  ('taken', 165),
#  ('bring', 165),
#  ('comment', 165),
#  ('compete', 164),
#  ('(not', 164),
#  ('area', 163),
#  ('8', 163),
#  ('...', 163),
#  ('performance.', 163),
#  ('life', 163),
#  ('repair', 163),
#  ('reviews', 163),
#  ('pricing', 163),
#  ('black', 162),
#  ('sort', 162),
#  ('sorry', 162),
#  ('article', 162),
#  ('basically', 162),
#  ('regarding', 162),
#  ('traffic', 162),
#  ('s60', 161),
#  ('whatever', 161),
#  ("you've", 161),
#  ('20', 161),
#  ('mazda', 161),
#  ('decision', 161),
#  ('regular', 161),
#  ('2008', 160),
#  ('style', 159),
#  ('plenty', 159),
#  ('absolutely', 158),
#  ('owner', 158),
#  ('gone', 158),
#  ('comfortable', 158),
#  ('early', 157),
#  ('v8', 157),
#  ('soft', 156),
#  ('hold', 156),
#  ('economy', 156),
#  ('year.', 155),
#  ('all,', 155),
#  ('slightly', 155),
#  ('reasons', 155),
#  ('personally', 154),
#  ('gave', 154),
#  ('not.', 154),
#  ('actual', 154),
#  ('marketing', 154),
#  ('wish', 154),
#  ('drive,', 153),
#  ('stuff', 153),
#  ('platform', 153),
#  ('forget', 153),
#  ('clutch', 153),
#  ('trip', 153),
#  ('either.', 152),
#  ('upon', 152),
#  ('traction', 152),
#  ('lbs', 152),
#  ('notice', 151),
#  ('become', 151),
#  ('horsepower', 150),
#  ('tried', 150),
#  ('oh', 150),
#  ('cpo', 150),
#  ('single', 149),
#  ('2003', 149),
#  ('brands', 149),
#  ('turned', 149),
#  ('beyond', 149),
#  ('week', 149),
#  ('+', 149),
#  ('replace', 149),
#  ('fact,', 148),
#  ('x', 148),
#  ('drop', 148),
#  ('m5', 148),
#  ('engine.', 148),
#  ('infiniti,', 147),
#  ('hand', 147),
#  ('tested', 147),
#  ('stated', 147),
#  ('competition', 147),
#  ('leave', 147),
#  ('opinions', 146),
#  ('possible', 146),
#  ('gives', 146),
#  ('included', 146),
#  ('feeling', 146),
#  ('changes', 146),
#  ('miles.', 146),
#  ('motor', 145),
#  ('asked', 145),
#  ('package,', 145),
#  ('running', 145),
#  ('all.', 144),
#  ('vehicle.', 144),
#  ('increase', 144),
#  ('general', 144),
#  ('weeks', 144),
#  ('seemed', 144),
#  ('bet', 143),
#  ('manual.', 143),
#  ('es', 143),
#  ('factory', 143),
#  ('mostly', 143),
#  ('seriously', 143),
#  ('mkz', 143),
#  ('admit', 142),
#  ('impressed', 142),
#  ('sedan,', 142),
#  ('category', 142),
#  ('nor', 142),
#  ('point.', 142),
#  ('buick', 141),
#  ('out,', 141),
#  ('entire', 141),
#  ('power,', 141),
#  ('designed', 141),
#  ('discount', 141),
#  ('magazine', 141),
#  ('obviously', 141),
#  ('surprised', 141),
#  ('seconds', 140),
#  ('shopping', 140),
#  ('3.0', 140),
#  ('comparable', 140),
#  ('normal', 140),
#  ('common', 139),
#  ('year,', 139),
#  ('changed', 139),
#  ('prestige', 139),
#  ('interested', 138),
#  ('quick', 138),
#  ('review', 138),
#  ('quattro', 138),
#  ('majority', 138),
#  ('advantage', 138),
#  ('interior,', 137),
#  ('wood', 137),
#  ('include', 137),
#  ('sitting', 137),
#  ('delivery', 136),
#  ('consumer', 135),
#  ('pull', 135),
#  ('figure', 135),
#  ('needed', 135),
#  ('air', 135),
#  ('buyer', 135),
#  ('tires.', 135),
#  ('product', 134),
#  ('a6', 134),
#  ('north', 134),
#  ('engineering', 134),
#  ('gotten', 134),
#  ('know,', 134),
#  ('comfort', 134),
#  ('sells', 134),
#  ('manufacturer', 134),
#  ('2002', 133),
#  ('leather,', 133),
#  ('step', 133),
#  ('them,', 133),
#  ('acura,', 133),
#  ('turning', 132),
#  ('tech', 132),
#  ('argue', 132),
#  ('street', 132),
#  ('knew', 132),
#  ('companies', 131),
#  ('statement', 131),
#  ('neither', 131),
#  ...]
